# %% [markdown]
# <a href="https://colab.research.google.com/github/AsmitaChorge/CYBER-WAVE/blob/main/Task2_CYBERWAVE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Movie Rating Prediction with python**

# %% [markdown]
# Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import chardet

# %% [markdown]
# importing dataset

# %%
# Use the chardet library to detect the encoding of the file
with open('/content/IMDb Movies India.csv', 'rb') as f:
    result = chardet.detect(f.read())

# Read the CSV file using the detected encoding
df = pd.read_csv('/content/IMDb Movies India.csv', encoding=result['encoding'])
df.head(10)
# Out:
#                                  Name    Year Duration  \
# 0                                         NaN      NaN
# 1  #Gadhvi (He thought he was Gandhi)  (2019)  109 min
# 2                         #Homecoming  (2021)   90 min
# 3                             #Yaaram  (2019)  110 min
# 4                   ...And Once Again  (2010)  105 min
# 5                ...Aur Pyaar Ho Gaya  (1997)  147 min
# 6                           ...Yahaan  (2005)  142 min
# 7                      .in for Motion  (2008)   59 min
# 8                  ?: A Question Mark  (2012)   82 min
# 9                            @Andheri  (2014)  116 min
#
#                        Genre  Rating  Votes            Director  \
# 0                      Drama     NaN    NaN       J.S. Randhawa
# 1                      Drama     7.0      8       Gaurav Bakshi
# 2             Drama, Musical     NaN    NaN  Soumyajit Majumdar
# 3            Comedy, Romance     4.4     35          Ovais Khan
# ...

# %%
df.describe()
# Out:
#             Rating
# count  7919.000000
# mean      5.841621
# std       1.381777
# min       1.100000
# 25%       4.900000
# 50%       6.000000
# 75%       6.800000
# max      10.000000

# %%
df.isna().sum()
# Out:
# Name           0
# Year         528
# Duration    8269
# Genre       1877
# Rating      7590
# Votes       7589
# Director     525
# Actor 1     1617
# Actor 2     2384
# Actor 3     3144
# dtype: int64

# %% [markdown]
# Data preprocessing

# %%
# Handle missing values
df = df.dropna()

# One-Hot Encoding for categorical features like 'genre', 'director', 'actors'
from sklearn.preprocessing import LabelEncoder
lebelencoder = LabelEncoder()

categorical_features = ['Genre', 'Director', 'Actor 1']
labelencoder = LabelEncoder() # remove arguments sparse and handle_unknown

# %% [markdown]
# Split Data into Train and Test Sets
